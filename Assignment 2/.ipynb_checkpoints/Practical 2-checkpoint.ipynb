# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_excel('PracticalData.xlsx')

# %%
data.head(5)
# Out:
#    Rollno Name Term  Attendence  Subject1_marks  Subject2_marks  \
# 0       1  abc    A        36.0            40.0            41.0
# 1       2  bcd    A        88.0            75.0             NaN
# 2       3  cde    A        20.0            54.0           100.0
# 3       4  def    A        58.0            64.0            66.0
# 4       5  efg    A        72.0            53.0            72.0
#
#    Subject3_marks  Subject4_marks  Subject5_marks  Total_Marks  Percentage  \
# 0            48.0            65.0            74.0          268        53.6
# 1             NaN            42.0             NaN          117        23.4
# 2            46.0            60.0            61.0          321        53.2
# 3            57.0            53.0            47.0          287        59.4
# 4            58.0            80.0            65.0          328        65.6
#
#   Result
# 0   Pass
# 1   Pass
# 2   Fail
# 3   Pass
# 4   Pass

# %%
data.shape
# Out:
# (30, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rollno          30 non-null     int64
#  1   Name            30 non-null     object
#  2   Term            30 non-null     object
#  3   Attendence      29 non-null     float64
#  4   Subject1_marks  28 non-null     float64
#  5   Subject2_marks  28 non-null     float64
#  6   Subject3_marks  27 non-null     float64
#  7   Subject4_marks  29 non-null     float64
#  8   Subject5_marks  28 non-null     float64
#  9   Total_Marks     30 non-null     int64
#  10  Percentage      30 non-null     float64
#  11  Result          30 non-null     object
# dtypes: float64(7), int64(2), object(3)
# memory usage: 2.9+ KB

# %%
data.dtypes.value_counts()
# Out:
# float64    7
# object     3
# int64      2
# dtype: int64

# %% [markdown]
# Handling the Missing values

# %%
#Handling the Missing values
data.isnull().sum()  
#columns having number of missing values
#Or we can also use command-> data.isna().sum()
# Out:
# Rollno            0
# Name              0
# Term              0
# Attendence        1
# Subject1_marks    2
# Subject2_marks    2
# Subject3_marks    3
# Subject4_marks    1
# Subject5_marks    2
# Total_Marks       0
# Percentage        0
# Result            0
# dtype: int64

# %%
cols = data.columns[data.isnull().any()].tolist()
print(cols)
#make a list of columns with missing values
# Out:
# ['Attendence', 'Subject1_marks', 'Subject2_marks', 'Subject3_marks', 'Subject4_marks', 'Subject5_marks']

# %% [markdown]
# Fill the missing value using mean for float and int datatypes and for other forword fill

# %%
for col in cols:
    col_dt = data[col].dtypes
    if (col_dt == 'int64' or col_dt == 'float64'):
        data_col = data[col]
        for i in range(data.shape[0]):
            if (data_col[i] < 0 or data_col[i] > 100):
                data_col[i] = np.nan
        data_col.fillna(data_col.mean(), inplace=True)
    else:
        data[col] = data[col].fillna(method='ffill')
# Out:
# C:\Users\avant\AppData\Local\Temp\ipykernel_2308\932612429.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_col[i] = np.nan

# %%
#check Missing values are removed or not
data.isnull().sum()
# Out:
# Rollno            0
# Name              0
# Term              0
# Attendence        0
# Subject1_marks    0
# Subject2_marks    0
# Subject3_marks    0
# Subject4_marks    0
# Subject5_marks    0
# Total_Marks       0
# Percentage        0
# Result            0
# dtype: int64

# %% [markdown]
# No missing data

# %% [markdown]
# Correction in Total Marks, Percentage after filling missing value

# %%
data['Total_Marks']=data['Subject1_marks']+data['Subject2_marks']+data['Subject3_marks']+data['Subject4_marks']+data['Subject5_marks']
data['Percentage']=data['Total_Marks']/5

# %%
data
# Out:
#     Rollno Name Term  Attendence  Subject1_marks  Subject2_marks  \
# 0        1  abc    A   36.000000       40.000000       41.000000
# 1        2  bcd    A   88.000000       75.000000       83.571429
# 2        3  cde    A   20.000000       54.000000      100.000000
# 3        4  def    A   58.000000       64.000000       66.000000
# 4        5  efg    A   72.000000       53.000000       72.000000
# 5        6  fgh    A   25.000000       49.000000       88.000000
# 6        7  ghi    A   90.000000       59.814815       78.000000
# 7        8  hij    A   36.000000       48.000000       92.000000
# 8        9  ijk    A   59.000000       78.000000       80.000000
# 9       10  jkl    A   82.000000       57.000000       75.000000
# 10      11  klm    A   34.000000       59.814815       99.000000
# 11      12  lmn    B   21.000000       72.000000       83.000000
# 12      13  mno    B   73.000000       60.000000       71.000000
# 13      14  nop    B   49.000000       59.814815       83.571429
# 14      15  opq    B   59.000000       51.000000       90.000000
# 15      16  pqr    B   61.000000       56.000000       74.000000
# 16      17  qrs    B   59.000000       72.000000       96.000000
# 17      18  rst    B   26.000000       56.000000       85.000000
# 18      19  stu    B   76.000000       80.000000       80.000000
# 19      20  tuv    B   56.000000       49.000000       93.000000
# 20      21  uvw    A   38.000000       56.000000      100.000000
# 21      22  vwx    A   79.000000       65.000000       87.000000
# 22      23  wxy    A   87.000000       64.000000       95.000000
# 23      24  xyz    A   60.000000       56.000000       90.000000
# 24      25  aaa    A   56.448276       60.000000       84.000000
# 25      26  bbb    A   22.000000       71.000000       91.000000
# 26      27  ccc    A   58.000000       68.000000       92.000000
# 27      28  ddd    A   89.000000       54.000000       77.000000
# 28      29  eee    A   55.000000       67.000000       89.000000
# 29      30  ggg    A   69.000000       40.000000       72.000000
#
#     Subject3_marks  Subject4_marks  Subject5_marks  Total_Marks  Percentage  \
# 0        48.000000       65.000000       74.000000          268        53.6
# 1        58.481481       42.000000       59.857143          117        23.4
# 2        46.000000       60.000000       61.000000          321        53.2
# 3        57.000000       53.000000       47.000000          287        59.4
# 4        58.000000       80.000000       65.000000          328        65.6
# 5        73.000000       45.000000       75.000000          330        58.0
# 6        67.000000       50.000000       61.000000          256        45.6
# 7        74.000000       46.000000       64.000000          324        57.2
# 8        72.000000       44.000000       42.000000          316        61.2
# 9        70.000000       59.000000       63.000000          324        64.8
# 10       58.481481       67.000000       78.000000          734        50.6
# 11       56.000000       49.000000       45.000000          305        54.8
# 12       53.000000       69.000000       46.000000          299        59.8
# 13       60.000000       47.000000       70.000000          177        35.4
# 14       74.000000       48.000000       47.000000          310        52.0
# 15       40.000000       54.000000       78.000000          302        60.4
# 16       68.000000       63.000000       69.000000          368        65.6
# 17       74.000000       75.000000       55.000000          345        63.0
# 18       56.000000       66.000000       53.000000          335        61.2
# 19       57.000000       73.000000       64.000000          336        61.2
# 20       41.000000       58.517241       43.000000          240        43.2
# 21       47.000000       60.000000       50.000000          309        56.0
# 22       44.000000       44.000000       53.000000          300        50.0
# 23       45.000000       47.000000       66.000000          304        56.8
# 24       61.000000       65.000000       53.000000          323        62.8
# 25       65.000000       64.000000       64.000000          355        67.6
# 26       79.000000       65.000000       62.000000          366        64.8
# 27       49.000000       75.000000       63.000000          318        63.6
# 28       58.481481       49.000000       59.857143          205        31.6
# 29       45.000000       73.000000       65.000000          295        59.0
#
#    Result
# 0    Pass
# 1    Pass
# 2    Fail
# 3    Pass
# 4    Pass
# 5    Pass
# 6    Pass
# 7    Pass
# 8    Pass
# 9    Pass
# 10   Pass
# 11   Pass
# 12   Pass
# 13   Pass
# 14   Fail
# 15   Pass
# 16   Pass
# 17   Pass
# 18   Pass
# 19   Pass
# 20   Pass
# 21   Pass
# 22   Pass
# 23   Pass
# 24   Pass
# 25   Pass
# 26   Pass
# 27   Pass
# 28   Pass
# 29   Fail

# %% [markdown]
# Outliers Detection

# %%
plt.rcParams["figure.figsize"] = (9, 6)
data_list = ['Attendence', 'Subject1_marks', 'Subject2_marks', 'Subject3_marks', 'Subject4_marks', 'Subject5_marks'] 
fig, axes = plt.subplots(2, 3)
fig.set_dpi(120)
count=0
for r in range(2):
	for c in range(3):
		data[data_list[count]].plot(kind = 'box', ax=axes[r,c])
		count+=1

# %% [markdown]
# Removal of Outliers from Subject2_marks

# %%
Q1 = data['Subject2_marks'].quantile(0.25)
Q3 = data['Subject2_marks'].quantile(0.75)
IQR = Q3 - Q1
Lower_limit = Q1 - 1.5 * IQR
Upper_limit = Q3 + 1.5 * IQR
print(f'Q1 = {Q1}, Q3 = {Q3}, IQR = {IQR}, Lower_limit = {Lower_limit}, Upper_limit = {Upper_limit}')
# Out:
# Q1 = 77.25, Q3 = 91.75, IQR = 14.5, Lower_limit = 55.5, Upper_limit = 113.5

# %%
data[(data['Subject2_marks'] < Lower_limit) | (data['Subject2_marks'] > Upper_limit)]
# Out:
#    Rollno Name Term  Attendence  Subject1_marks  Subject2_marks  \
# 0       1  abc    A        36.0            40.0            41.0
#
#    Subject3_marks  Subject4_marks  Subject5_marks  Total_Marks  Percentage  \
# 0            48.0            65.0            74.0          268        53.6
#
#   Result
# 0   Pass

# %%
data[(data['Subject2_marks'] < Lower_limit) & (data['Subject2_marks'] > Upper_limit)]
# Out:
# Empty DataFrame
# Columns: [Rollno, Name, Term, Attendence, Subject1_marks, Subject2_marks, Subject3_marks, Subject4_marks, Subject5_marks, Total_Marks, Percentage, Result]
# Index: []

# %%
plt.rcParams["figure.figsize"] = (9, 6)
data_list = ['Attendence', 'Subject1_marks', 'Subject2_marks', 'Subject3_marks', 'Subject4_marks', 'Subject5_marks'] 
fig, axes = plt.subplots(2, 3)
fig.set_dpi(120)
count=0
for r in range(2):
	for c in range(3):
		data[data_list[count]].plot(kind = 'box', ax=axes[r,c])
		count+=1

# %% [markdown]
# Convert Into Normal Distribution

# %%
data['Total_Marks_Scaled'] = (data['Total_Marks'] - data['Total_Marks'].min()) / (data['Total_Marks'].max() - data['Total_Marks'].min())

# %%
data.head()
# Out:
#    Rollno Name Term  Attendence  Subject1_marks  Subject2_marks  \
# 0       1  abc    A        36.0            40.0       41.000000
# 1       2  bcd    A        88.0            75.0       83.571429
# 2       3  cde    A        20.0            54.0      100.000000
# 3       4  def    A        58.0            64.0       66.000000
# 4       5  efg    A        72.0            53.0       72.000000
#
#    Subject3_marks  Subject4_marks  Subject5_marks  Total_Marks  Percentage  \
# 0       48.000000            65.0       74.000000          268        53.6
# 1       58.481481            42.0       59.857143          117        23.4
# 2       46.000000            60.0       61.000000          321        53.2
# 3       57.000000            53.0       47.000000          287        59.4
# 4       58.000000            80.0       65.000000          328        65.6
#
#   Result
# 0   Pass
# 1   Pass
# 2   Fail
# 3   Pass
# 4   Pass
